# %% [markdown]
# ## Ref
#
# - https://developer.spotify.com/documentation/web-api/reference/get-recommendations - recommendations API
# - https://developer.spotify.com/documentation/web-api/reference/get-audio-features - get song feature
# - https://github.com/spotify-web-api-java/spotify-web-api-java - Java client
# - https://jitpack.io/p/lbengzon/spotify-web-api-java
# - https://github.com/yennanliu/nelson/blob/master/server.js#L88
# - https://nelson.glitch.me/#
# - https://github.com/hardikSinghBehl/spotifyApiSpring/tree/master - other project in java

# %%
#----------------------------------------
# MAIN CODE
#----------------------------------------

# %%
import requests

# Set your Spotify client ID and client secret
client_id=""
client_secret=""


# Define the token request data
token_data = {
    "grant_type": "client_credentials"
}

# Set the token request URL
token_url = "https://accounts.spotify.com/api/token"

# Set the headers with your client ID and client secret
headers = {
    "Content-Type": "application/x-www-form-urlencoded"
}

# Send the POST request to get the token
response = requests.post(token_url, data=token_data, headers=headers, auth=(client_id, client_secret))

# Check if the request was successful
if response.status_code == 200:
    access_token = response.json().get('access_token')
    print(f"Access Token: {access_token}")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Access Token: BQDd-wPiNVS58goNCNzQMtQ_1WSi-1MbszEj0R1Nz9yUYrYV15GllGkC-fOw74tFTx2Mqj2fuAbCs6ktCBZk4Ud_EB6Eh45Qkum1R0ICYM-fGK7HK7I

# %%
# Help func

def api_call(url, token):
    print("url = " + str(url) + "token = " + str(token))
    headers = {
    "Authorization": f"Bearer {access_token}"
    }
    # Send the GET request to the Spotify API
    response = requests.get(url, headers=headers)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        # Process the data as needed
        #print(data)
        return data
    else:
        print(f"Error: {response.status_code} - {response.text}")

# %%
# 1) Get albums detail

url_1 = "https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy"

res_1 = api_call(url_1, access_token)
print(res_1.keys())
# Out:
# url = https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTytoken = BQDd-wPiNVS58goNCNzQMtQ_1WSi-1MbszEj0R1Nz9yUYrYV15GllGkC-fOw74tFTx2Mqj2fuAbCs6ktCBZk4Ud_EB6Eh45Qkum1R0ICYM-fGK7HK7I
# dict_keys(['album_type', 'total_tracks', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'type', 'uri', 'artists', 'tracks', 'copyrights', 'external_ids', 'genres', 'label', 'popularity'])

# %%
# 2) Get song detail

url_2 = "https://api.spotify.com/v1/audio-features/11dFghVXANMlKmJXsNCbNl"

res_2 = api_call(url_2, access_token)
# Out:
# url = https://api.spotify.com/v1/audio-features/11dFghVXANMlKmJXsNCbNltoken = BQDd-wPiNVS58goNCNzQMtQ_1WSi-1MbszEj0R1Nz9yUYrYV15GllGkC-fOw74tFTx2Mqj2fuAbCs6ktCBZk4Ud_EB6Eh45Qkum1R0ICYM-fGK7HK7I

# %%
print(res_2.keys())
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %%
# 3) Call recommendation API

url_3 = "https://api.spotify.com/v1/recommendations?seed_artists=4NHQUGzhtTLFvgF5SZesLK&seed_genres=classical%2Ccountry&seed_tracks=0c6xIDDpzE81m2q797ordA"

res_3 = api_call(url_3, access_token)

print(res_3.keys())
# Out:
# url = https://api.spotify.com/v1/recommendations?seed_artists=4NHQUGzhtTLFvgF5SZesLK&seed_genres=classical%2Ccountry&seed_tracks=0c6xIDDpzE81m2q797ordAtoken = BQDd-wPiNVS58goNCNzQMtQ_1WSi-1MbszEj0R1Nz9yUYrYV15GllGkC-fOw74tFTx2Mqj2fuAbCs6ktCBZk4Ud_EB6Eh45Qkum1R0ICYM-fGK7HK7I
# dict_keys(['tracks', 'seeds'])

# %%
# 3) Call recommendation API

url_3_1 = "https://api.spotify.com/v1/recommendations?seed_genres=classical%2Ccountry"

res_3_1 = api_call(url_3_1, access_token)

print(res_3_1.keys())

res_3_1
# Out:
# url = https://api.spotify.com/v1/recommendations?seed_genres=classical%2Ccountrytoken = BQDd-wPiNVS58goNCNzQMtQ_1WSi-1MbszEj0R1Nz9yUYrYV15GllGkC-fOw74tFTx2Mqj2fuAbCs6ktCBZk4Ud_EB6Eh45Qkum1R0ICYM-fGK7HK7I
# dict_keys(['tracks', 'seeds'])
# {'tracks': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Zn69emN3uZsF6YwCrkgYp'},
#       'href': 'https://api.spotify.com/v1/artists/1Zn69emN3uZsF6YwCrkgYp',
#       'id': '1Zn69emN3uZsF6YwCrkgYp',
#       'name': 'Trent Tomlinson',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Zn69emN3uZsF6YwCrkgYp'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1dMtfygDergsiS0sep6KDL'},
#     'href': 'https://api.spotify.com/v1/albums/1dMtfygDergsiS0sep6KDL',
#     'id': '1dMtfygDergsiS0sep6KDL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ffae8e2e27a24beaf16c921b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ffae8e2e27a24beaf16c921b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ffae8e2e27a24beaf16c921b',
#       'width': 64}],
#     'name': 'Country Is My Rock',
#     'release_date': '2006-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1dMtfygDergsiS0sep6KDL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Zn69emN3uZsF6YwCrkgYp'},
#      'href': 'https://api.spotify.com/v1/artists/1Zn69emN3uZsF6YwCrkgYp',
#      'id': '1Zn69emN3uZsF6YwCrkgYp',
#      'name': 'Trent Tomlinson',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Zn69emN3uZsF6YwCrkgYp'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 232546,
#    'explicit': False,
#    'external_ids': {'isrc': 'USL2S0620207'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/338arfXmD9XaESFjfcQLsg'},
#    'href': 'https://api.spotify.com/v1/tracks/338arfXmD9XaESFjfcQLsg',
#    'id': '338arfXmD9XaESFjfcQLsg',
#    'is_local': False,
#    'name': 'One Wing In The Fire',
#    'popularity': 41,
#    'preview_url': None,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:338arfXmD9XaESFjfcQLsg'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bM3j1JQWBkmzuoZKu4zj2'},
#       'href': 'https://api.spotify.com/v1/artists/2bM3j1JQWBkmzuoZKu4zj2',
#       'id': '2bM3j1JQWBkmzuoZKu4zj2',
#       'name': 'Anton Bruckner',
#       'type': 'artist',
#       'uri': 'spotify:artist:2bM3j1JQWBkmzuoZKu4zj2'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5UpK57VBAZQ03iTyX5JlXB'},
#       'href': 'https://api.spotify.com/v1/artists/5UpK57VBAZQ03iTyX5JlXB',
#       'id': '5UpK57VBAZQ03iTyX5JlXB',
#       'name': 'Jaap Van Zweden',
#       'type': 'artist',
#       'uri': 'spotify:artist:5UpK57VBAZQ03iTyX5JlXB'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2EhbrNPFChfign8igrNXG7'},
#     'href': 'https://api.spotify.com/v1/albums/2EhbrNPFChfign8igrNXG7',
#     'id': '2EhbrNPFChfign8igrNXG7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27325608ee6e98c09f31a117963',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0225608ee6e98c09f31a117963',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485125608ee6e98c09f31a117963',
#       'width': 64}],
#     'name': 'Bruckner: Symphony No. 1',
#     'release_date': '2015-04-30',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:2EhbrNPFChfign8igrNXG7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bM3j1JQWBkmzuoZKu4zj2'},
#      'href': 'https://api.spotify.com/v1/artists/2bM3j1JQWBkmzuoZKu4zj2',
#      'id': '2bM3j1JQWBkmzuoZKu4zj2',
#      'name': 'Anton Bruckner',
#      'type': 'artist',
#      'uri': 'spotify:artist:2bM3j1JQWBkmzuoZKu4zj2'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5UpK57VBAZQ03iTyX5JlXB'},
#      'href': 'https://api.spotify.com/v1/artists/5UpK57VBAZQ03iTyX5JlXB',
#      'id': '5UpK57VBAZQ03iTyX5JlXB',
#      'name': 'Jaap Van Zweden',
#      'type': 'artist',
#      'uri': 'spotify:artist:5UpK57VBAZQ03iTyX5JlXB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5DNIeOqK0YF4H6o3GM2k6C'},
#      'href': 'https://api.spotify.com/v1/artists/5DNIeOqK0YF4H6o3GM2k6C',
#      'id': '5DNIeOqK0YF4H6o3GM2k6C',
#      'name': 'Netherlands Radio Philharmonic Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:5DNIeOqK0YF4H6o3GM2k6C'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 802026,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLB151500157'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7qBdLnaOLZq3mwsuTkR3QI'},
#    'href': 'https://api.spotify.com/v1/tracks/7qBdLnaOLZq3mwsuTkR3QI',
#    'id': '7qBdLnaOLZq3mwsuTkR3QI',
#    'is_local': False,
#    'name': 'Symphony No. 1 in C Minor, WAB 101 - Edition Nowak (Linzer Fassung, 1866): I. Allegro',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a15812e18ad35be20efa8b3fe01fe672aa479dc4?cid=833e496a818d4dac926a00970ba4d725',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7qBdLnaOLZq3mwsuTkR3QI'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EhgpjUqiIIQhM6ZRF4kXX'},
#       'href': 'https://api.spotify.com/v1/artists/0EhgpjUqiIIQhM6ZRF4kXX',
#       'id': '0EhgpjUqiIIQhM6ZRF4kXX',
#       'name': 'Pat Green',
#       'type': 'artist',
#       'uri': 'spotify:artist:0EhgpjUqiIIQhM6ZRF4kXX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BD',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GN',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KH',
#      'KR',
#      'LA',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MK',
#      'MU',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'RW',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'VE',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0HjdNkgyrUKC2ynRUNna7V'},
#     'href': 'https://api.spotify.com/v1/albums/0HjdNkgyrUKC2ynRUNna7V',
#     'id': '0HjdNkgyrUKC2ynRUNna7V',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738d15e09865bdf066c4a8307a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028d15e09865bdf066c4a8307a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518d15e09865bdf066c4a8307a',
#       'width': 64}],
#     'name': 'Wave On Wave',
#     'release_date': '2003-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:0HjdNkgyrUKC2ynRUNna7V'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EhgpjUqiIIQhM6ZRF4kXX'},
#      'href': 'https://api.spotify.com/v1/artists/0EhgpjUqiIIQhM6ZRF4kXX',
#      'id': '0EhgpjUqiIIQhM6ZRF4kXX',
#      'name': 'Pat Green',
#      'type': 'artist',
#      'uri': 'spotify:artist:0EhgpjUqiIIQhM6ZRF4kXX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BD',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GN',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JP',
#     'KH',
#     'KR',
#     'LA',
#     'LI',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MK',
#     'MU',
#     'MX',
#     'MY',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'RW',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'VE',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 244373,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUR10300474'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7rS87NoPWbAkVURdVFbGH9'},
#    'href': 'https://api.spotify.com/v1/tracks/7rS87NoPWbAkVURdVFbGH9',
#    'id': '7rS87NoPWbAkVURdVFbGH9',
#    'is_local': False,
#    'name': 'Wave on Wave',
#    'popularity': 53,
#    'preview_url': None,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:7rS87NoPWbAkVURdVFbGH9'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/147nKr9upHZSSxqCzh9j7c'},
#       'href': 'https://api.spotify.com/v1/artists/147nKr9upHZSSxqCzh9j7c',
#       'id': '147nKr9upHZSSxqCzh9j7c',
#       'name': 'Jimmie Allen',
#       'type': 'artist',
#       'uri': 'spotify:artist:147nKr9upHZSSxqCzh9j7c'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7EpN0TPMSMqGKVjIEzc0Ts'},
#     'href': 'https://api.spotify.com/v1/albums/7EpN0TPMSMqGKVjIEzc0Ts',
#     'id': '7EpN0TPMSMqGKVjIEzc0Ts',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730f053241d2934c00e3b8ae95',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020f053241d2934c00e3b8ae95',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510f053241d2934c00e3b8ae95',
#       'width': 64}],
#     'name': 'Mercury Lane',
#     'release_date': '2018-10-12',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:7EpN0TPMSMqGKVjIEzc0Ts'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/147nKr9upHZSSxqCzh9j7c'},
#      'href': 'https://api.spotify.com/v1/artists/147nKr9upHZSSxqCzh9j7c',
#      'id': '147nKr9upHZSSxqCzh9j7c',
#      'name': 'Jimmie Allen',
#      'type': 'artist',
#      'uri': 'spotify:artist:147nKr9upHZSSxqCzh9j7c'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 195053,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMRSZ1702666'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3VamXAvVMczcS2PTYtPfBQ'},
#    'href': 'https://api.spotify.com/v1/tracks/3VamXAvVMczcS2PTYtPfBQ',
#    'id': '3VamXAvVMczcS2PTYtPfBQ',
#    'is_local': False,
#    'name': 'Best Shot',
#    'popularity': 2,
#    'preview_url': None,
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:3VamXAvVMczcS2PTYtPfBQ'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nf0nRF0W4ybnJdda00pKY'},
#       'href': 'https://api.spotify.com/v1/artists/1nf0nRF0W4ybnJdda00pKY',
#       'id': '1nf0nRF0W4ybnJdda00pKY',
#       'name': 'The Swon Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:1nf0nRF0W4ybnJdda00pKY'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1CmyiTVCeiB2FTlxK1afes'},
#     'href': 'https://api.spotify.com/v1/albums/1CmyiTVCeiB2FTlxK1afes',
#     'id': '1CmyiTVCeiB2FTlxK1afes',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731c93430b7707763837b4c7d2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021c93430b7707763837b4c7d2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511c93430b7707763837b4c7d2',
#       'width': 64}],
#     'name': 'What Ever Happened',
#     'release_date': '2018-02-23',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1CmyiTVCeiB2FTlxK1afes'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nf0nRF0W4ybnJdda00pKY'},
#      'href': 'https://api.spotify.com/v1/artists/1nf0nRF0W4ybnJdda00pKY',
#      'id': '1nf0nRF0W4ybnJdda00pKY',
#      'name': 'The Swon Brothers',
#      'type': 'artist',
#      'uri': 'spotify:artist:1nf0nRF0W4ybnJdda00pKY'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 220010,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZ5AB1864880'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6K2DEAxxbtp7yAsvqYzgOn'},
#    'href': 'https://api.spotify.com/v1/tracks/6K2DEAxxbtp7yAsvqYzgOn',
#    'id': '6K2DEAxxbtp7yAsvqYzgOn',
#    'is_local': False,
#    'name': 'What Ever Happened',
#    'popularity': 15,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7d7aa7ed6d2ab46255527850471061db27a8fa08?cid=833e496a818d4dac926a00970ba4d725',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6K2DEAxxbtp7yAsvqYzgOn'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13CMfEeq8AC6ryGOPODqE1'},
#       'href': 'https://api.spotify.com/v1/artists/13CMfEeq8AC6ryGOPODqE1',
#       'id': '13CMfEeq8AC6ryGOPODqE1',
#       'name': 'A Winged Victory for the Sullen',
#       'type': 'artist',
#       'uri': 'spotify:artist:13CMfEeq8AC6ryGOPODqE1'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vygseD1InhHomosteUnPU'},
#     'href': 'https://api.spotify.com/v1/albums/6vygseD1InhHomosteUnPU',
#     'id': '6vygseD1InhHomosteUnPU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739df0943f217d265ed44259a9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029df0943f217d265ed44259a9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519df0943f217d265ed44259a9',
#       'width': 64}],
#     'name': 'A Winged Victory for the Sullen',
#     'release_date': '2011-09-12',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:6vygseD1InhHomosteUnPU'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13CMfEeq8AC6ryGOPODqE1'},
#      'href': 'https://api.spotify.com/v1/artists/13CMfEeq8AC6ryGOPODqE1',
#      'id': '13CMfEeq8AC6ryGOPODqE1',
#      'name': 'A Winged Victory for the Sullen',
#      'type': 'artist',
#      'uri': 'spotify:artist:13CMfEeq8AC6ryGOPODqE1'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'disc_number': 1,
#    'duration_ms': 378573,
#    'explicit': False,
#    'external_ids': {'isrc': 'USNCB1115701'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4Wa9WkQSacZDsJQgov27DA'},
#    'href': 'https://api.spotify.com/v1/tracks/4Wa9WkQSacZDsJQgov27DA',
#    'id': '4Wa9WkQSacZDsJQgov27DA',
#    'is_local': False,
#    'name': 'We Played Some Open Chords',
#    'popularity': 28,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d0091e92d7075882ee1eab987898c09c7d3f5be8?cid=833e496a818d4dac926a00970ba4d725',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4Wa9WkQSacZDsJQgov27DA'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rJqqRce0Kvo2dJUXoHleC'},
#       'href': 'https://api.spotify.com/v1/artists/6rJqqRce0Kvo2dJUXoHleC',
#       'id': '6rJqqRce0Kvo2dJUXoHleC',
#       'name': 'Alabama',
#       'type': 'artist',
#       'uri': 'spotify:artist:6rJqqRce0Kvo2dJUXoHleC'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4w1Z4XZAaXXO6FLLNp6pU3'},
#     'href': 'https://api.spotify.com/v1/albums/4w1Z4XZAaXXO6FLLNp6pU3',
#     'id': '4w1Z4XZAaXXO6FLLNp6pU3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273969a6ae8a3991e4374de2d29',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02969a6ae8a3991e4374de2d29',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851969a6ae8a3991e4374de2d29',
#       'width': 64}],
#     'name': '40 Hour Week',
#     'release_date': '1985',
#     'release_date_precision': 'year',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4w1Z4XZAaXXO6FLLNp6pU3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rJqqRce0Kvo2dJUXoHleC'},
#      'href': 'https://api.spotify.com/v1/artists/6rJqqRce0Kvo2dJUXoHleC',
#      'id': '6rJqqRce0Kvo2dJUXoHleC',
#      'name': 'Alabama',
#      'type': 'artist',
#      'uri': 'spotify:artist:6rJqqRce0Kvo2dJUXoHleC'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 203000,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRN18500006'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5995mHLcqAJBX60f3iaCeq'},
#    'href': 'https://api.spotify.com/v1/tracks/5995mHLcqAJBX60f3iaCeq',
#    'id': '5995mHLcqAJBX60f3iaCeq',
#    'is_local': False,
#    'name': "Forty Hour Week (For a Livin')",
#    'popularity': 27,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9e1af62538d23a846aa46160e97987291226790f?cid=833e496a818d4dac926a00970ba4d725',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5995mHLcqAJBX60f3iaCeq'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70kkdajctXSbqSMJbQO424'},
#       'href': 'https://api.spotify.com/v1/artists/70kkdajctXSbqSMJbQO424',
#       'id': '70kkdajctXSbqSMJbQO424',
#       'name': 'Kacey Musgraves',
#       'type': 'artist',
#       'uri': 'spotify:artist:70kkdajctXSbqSMJbQO424'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6IGpQUt0KNi5rBUXZZOFI6'},
#     'href': 'https://api.spotify.com/v1/albums/6IGpQUt0KNi5rBUXZZOFI6',
#     'id': '6IGpQUt0KNi5rBUXZZOFI6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27327276e651476643cd5c10e71',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0227276e651476643cd5c10e71',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485127276e651476643cd5c10e71',
#       'width': 64}],
#     'name': 'Same Trailer Different Park',
#     'release_date': '2013-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6IGpQUt0KNi5rBUXZZOFI6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/70kkdajctXSbqSMJbQO424'},
#      'href': 'https://api.spotify.com/v1/artists/70kkdajctXSbqSMJbQO424',
#      'id': '70kkdajctXSbqSMJbQO424',
#      'name': 'Kacey Musgraves',
#      'type': 'artist',
#      'uri': 'spotify:artist:70kkdajctXSbqSMJbQO424'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 199640,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71300707'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4CLPNURPcKztF9RRdcWLGP'},
#    'href': 'https://api.spotify.com/v1/tracks/4CLPNURPcKztF9RRdcWLGP',
#    'id': '4CLPNURPcKztF9RRdcWLGP',
#    'is_local': False,
#    'name': 'Follow Your Arrow',
#    'popularity': 61,
#    'preview_url': None,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:4CLPNURPcKztF9RRdcWLGP'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2p0UyoPfYfI76PCStuXfOP'},
#       'href': 'https://api.spotify.com/v1/artists/2p0UyoPfYfI76PCStuXfOP',
#       'id': '2p0UyoPfYfI76PCStuXfOP',
#       'name': 'Franz Schubert',
#       'type': 'artist',
#       'uri': 'spotify:artist:2p0UyoPfYfI76PCStuXfOP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2BoWH2w47EUxEiOuvl4mxF'},
#       'href': 'https://api.spotify.com/v1/artists/2BoWH2w47EUxEiOuvl4mxF',
#       'id': '2BoWH2w47EUxEiOuvl4mxF',
#       'name': 'Radu Lupu',
#       'type': 'artist',
#       'uri': 'spotify:artist:2BoWH2w47EUxEiOuvl4mxF'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'EG',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'TJ',
#      'VE',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0b4yWvYYIzFLLnxwxNumUg'},
#     'href': 'https://api.spotify.com/v1/albums/0b4yWvYYIzFLLnxwxNumUg',
#     'id': '0b4yWvYYIzFLLnxwxNumUg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bfd44e45b62bbdbaa1553803',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bfd44e45b62bbdbaa1553803',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bfd44e45b62bbdbaa1553803',
#       'width': 64}],
#     'name': 'Schubert: Piano Sonatas in A major; A minor; E major',
#     'release_date': '1991-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:0b4yWvYYIzFLLnxwxNumUg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2p0UyoPfYfI76PCStuXfOP'},
#      'href': 'https://api.spotify.com/v1/artists/2p0UyoPfYfI76PCStuXfOP',
#      'id': '2p0UyoPfYfI76PCStuXfOP',
#      'name': 'Franz Schubert',
#      'type': 'artist',
#      'uri': 'spotify:artist:2p0UyoPfYfI76PCStuXfOP'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2BoWH2w47EUxEiOuvl4mxF'},
#      'href': 'https://api.spotify.com/v1/artists/2BoWH2w47EUxEiOuvl4mxF',
#      'id': '2BoWH2w47EUxEiOuvl4mxF',
#      'name': 'Radu Lupu',
#      'type': 'artist',
#      'uri': 'spotify:artist:2BoWH2w47EUxEiOuvl4mxF'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'EG',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'TJ',
#     'VE',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 673826,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBF077510844'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2UEer5v08SeaipCQuO4QNb'},
#    'href': 'https://api.spotify.com/v1/tracks/2UEer5v08SeaipCQuO4QNb',
#    'id': '2UEer5v08SeaipCQuO4QNb',
#    'is_local': False,
#    'name': 'Piano Sonata No. 20 In A Major, D.959: 4. Rondo (Allegretto)',
#    'popularity': 11,
#    'preview_url': None,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2UEer5v08SeaipCQuO4QNb'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eSXFv3Ll2MEHf0eSAYJGu'},
#       'href': 'https://api.spotify.com/v1/artists/5eSXFv3Ll2MEHf0eSAYJGu',
#       'id': '5eSXFv3Ll2MEHf0eSAYJGu',
#       'name': 'James MacMillan',
#       'type': 'artist',
#       'uri': 'spotify:artist:5eSXFv3Ll2MEHf0eSAYJGu'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2B7g3x3ODIEjpdoOLIoa2C'},
#       'href': 'https://api.spotify.com/v1/artists/2B7g3x3ODIEjpdoOLIoa2C',
#       'id': '2B7g3x3ODIEjpdoOLIoa2C',
#       'name': 'Nicholas Daniel',
#       'type': 'artist',
#       'uri': 'spotify:artist:2B7g3x3ODIEjpdoOLIoa2C'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3P1VtkpIYbw6YoTo0KYlxy'},
#       'href': 'https://api.spotify.com/v1/artists/3P1VtkpIYbw6YoTo0KYlxy',
#       'id': '3P1VtkpIYbw6YoTo0KYlxy',
#       'name': 'Britten Sinfonia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3P1VtkpIYbw6YoTo0KYlxy'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
# ...
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4AwUix40p2isD6wvEBPpQ8'},
#     'href': 'https://api.spotify.com/v1/albums/4AwUix40p2isD6wvEBPpQ8',
#     'id': '4AwUix40p2isD6wvEBPpQ8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733bcc42fdc5fd354a3e58a03c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023bcc42fdc5fd354a3e58a03c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513bcc42fdc5fd354a3e58a03c',
#       'width': 64}],
#     'name': 'Haywire',
#     'release_date': '2010',
#     'release_date_precision': 'year',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:4AwUix40p2isD6wvEBPpQ8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7vCtweS8UVAXTyau2j0rDT'},
#      'href': 'https://api.spotify.com/v1/artists/7vCtweS8UVAXTyau2j0rDT',
#      'id': '7vCtweS8UVAXTyau2j0rDT',
#      'name': 'Josh Turner',
#      'type': 'artist',
#      'uri': 'spotify:artist:7vCtweS8UVAXTyau2j0rDT'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 192800,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70979834'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2p07VcUwRZ5sru3mJ0JogS'},
#    'href': 'https://api.spotify.com/v1/tracks/2p07VcUwRZ5sru3mJ0JogS',
#    'id': '2p07VcUwRZ5sru3mJ0JogS',
#    'is_local': False,
#    'name': "Why Don't We Just Dance",
#    'popularity': 68,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2p07VcUwRZ5sru3mJ0JogS'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6evVLxWyiwmi8gDtHn1Vzx'},
#       'href': 'https://api.spotify.com/v1/artists/6evVLxWyiwmi8gDtHn1Vzx',
#       'id': '6evVLxWyiwmi8gDtHn1Vzx',
#       'name': 'Percy Grainger',
#       'type': 'artist',
#       'uri': 'spotify:artist:6evVLxWyiwmi8gDtHn1Vzx'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0G5MVoVSyhU2rNpSHWwjV6'},
#     'href': 'https://api.spotify.com/v1/albums/0G5MVoVSyhU2rNpSHWwjV6',
#     'id': '0G5MVoVSyhU2rNpSHWwjV6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273acefae829824525140090a26',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02acefae829824525140090a26',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851acefae829824525140090a26',
#       'width': 64}],
#     'name': 'Percy Grainger: The Power Of Love',
#     'release_date': '1998-04-17',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0G5MVoVSyhU2rNpSHWwjV6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6evVLxWyiwmi8gDtHn1Vzx'},
#      'href': 'https://api.spotify.com/v1/artists/6evVLxWyiwmi8gDtHn1Vzx',
#      'id': '6evVLxWyiwmi8gDtHn1Vzx',
#      'name': 'Percy Grainger',
#      'type': 'artist',
#      'uri': 'spotify:artist:6evVLxWyiwmi8gDtHn1Vzx'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/428GNN7qZnTsMaK3SfPo6D'},
#      'href': 'https://api.spotify.com/v1/artists/428GNN7qZnTsMaK3SfPo6D',
#      'id': '428GNN7qZnTsMaK3SfPo6D',
#      'name': 'Slovak Radio Symphony Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:428GNN7qZnTsMaK3SfPo6D'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 336733,
#    'explicit': False,
#    'external_ids': {'isrc': 'HKI199716805'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2r2hR9gGMdusndlRzhM0cc'},
#    'href': 'https://api.spotify.com/v1/tracks/2r2hR9gGMdusndlRzhM0cc',
#    'id': '2r2hR9gGMdusndlRzhM0cc',
#    'is_local': False,
#    'name': 'Colonial Song',
#    'popularity': 11,
#    'preview_url': 'https://p.scdn.co/mp3-preview/55f72966405a500fd9047a72b58649fab8b6fc82?cid=833e496a818d4dac926a00970ba4d725',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:2r2hR9gGMdusndlRzhM0cc'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/738OS3zrCO782uDiUN9pet'},
#       'href': 'https://api.spotify.com/v1/artists/738OS3zrCO782uDiUN9pet',
#       'id': '738OS3zrCO782uDiUN9pet',
#       'name': 'Lee Ann Womack',
#       'type': 'artist',
#       'uri': 'spotify:artist:738OS3zrCO782uDiUN9pet'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5NwzdF5qHEtXT6SepzhWJv'},
#     'href': 'https://api.spotify.com/v1/albums/5NwzdF5qHEtXT6SepzhWJv',
#     'id': '5NwzdF5qHEtXT6SepzhWJv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27363b3168c1970294e9ce5c415',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0263b3168c1970294e9ce5c415',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485163b3168c1970294e9ce5c415',
#       'width': 64}],
#     'name': 'I Hope You Dance',
#     'release_date': '2000-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5NwzdF5qHEtXT6SepzhWJv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/738OS3zrCO782uDiUN9pet'},
#      'href': 'https://api.spotify.com/v1/artists/738OS3zrCO782uDiUN9pet',
#      'id': '738OS3zrCO782uDiUN9pet',
#      'name': 'Lee Ann Womack',
#      'type': 'artist',
#      'uri': 'spotify:artist:738OS3zrCO782uDiUN9pet'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 294533,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMCN0000018'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/65B1tEOv5W294uCKbmEcFV'},
#    'href': 'https://api.spotify.com/v1/tracks/65B1tEOv5W294uCKbmEcFV',
#    'id': '65B1tEOv5W294uCKbmEcFV',
#    'is_local': False,
#    'name': 'I Hope You Dance',
#    'popularity': 61,
#    'preview_url': None,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:65B1tEOv5W294uCKbmEcFV'}],
#  'seeds': [{'initialPoolSize': 517,
#    'afterFilteringSize': 517,
#    'afterRelinkingSize': 517,
#    'id': 'classical',
#    'type': 'GENRE',
#    'href': None},
#   {'initialPoolSize': 999,
#    'afterFilteringSize': 626,
#    'afterRelinkingSize': 626,
#    'id': 'country',
#    'type': 'GENRE',
#    'href': None}]}

# %%
# 4) Get songs from one of my playlists:
# TODO :
# 1) get song id from playlist
# 2) fetch song feature

url_4 = "https://api.spotify.com/v1/playlists/3EMYUexboFY1ShvAckNyAx?si=cf9194c40bd846e6"
res_4 = api_call(url_4, access_token)
# Out:
# url = https://api.spotify.com/v1/playlists/3EMYUexboFY1ShvAckNyAx?si=cf9194c40bd846e6token = BQDd-wPiNVS58goNCNzQMtQ_1WSi-1MbszEj0R1Nz9yUYrYV15GllGkC-fOw74tFTx2Mqj2fuAbCs6ktCBZk4Ud_EB6Eh45Qkum1R0ICYM-fGK7HK7I

# %%
res_4.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
for item in res_4["tracks"]["items"]:
  print (item["track"]["album"]["external_urls"]["spotify"])
# Out:
# https://open.spotify.com/album/1AtPpQ0av1ugXZ1QhjMQkK
# https://open.spotify.com/album/3Ekah2mVUZIojooFSaIskA
# https://open.spotify.com/album/3uwnm9XzBRExM28JllO23M
# https://open.spotify.com/album/3O93FYTqYYaT096AzvZHBm
# https://open.spotify.com/album/5TCUUYm1YSdBEIUX8fdZhj
# https://open.spotify.com/album/6UnoV72YbVs3govx24gDds
# https://open.spotify.com/album/4U7dNrhS6ITV4wb7A464nK
# https://open.spotify.com/album/6t8mEVN8w8ZtAB94tLrG96
# https://open.spotify.com/album/7oMz6bjlX6lPjG9iS5uV5y
# https://open.spotify.com/album/1wB0GF3mOb21xgSTuHBZ80
# https://open.spotify.com/album/4nyNnOXb8GtIei89Y88HWa
# https://open.spotify.com/album/0UpzcwYzTv2bexQrNwboyh
# https://open.spotify.com/album/6q8BNcH6wkWwWC0fGoJwkS
# https://open.spotify.com/album/74LSOp5FSRJFoMMhLpltKz
# https://open.spotify.com/album/7HiLx59YGgJT4zh5j6UIli
# https://open.spotify.com/album/041caKxkgE2dApfPYsR5qE
# https://open.spotify.com/album/62SB9GdMdVA5dog0Om9huj
# https://open.spotify.com/album/2y6m00PP2v0veE8lTemN73
# https://open.spotify.com/album/09GalPugs4ZBrI0rrLQPf6
# https://open.spotify.com/album/12wAKwJC0xf2cfTCZXlxpF
# https://open.spotify.com/album/1n85xHbGGkbPfSPUdgxb4Z
# https://open.spotify.com/album/6FveLW4LtU2O0wvBLiMmDp
# https://open.spotify.com/album/3o25bjGT9dYDin1fNlQkQj
# https://open.spotify.com/album/1HDyC7mRnfsfXnztjRPdPb
# https://open.spotify.com/album/5rA7l87Gxow5vfEU4tVMiG
# https://open.spotify.com/album/5KiitS2OkzuXQK68q32V8s
# https://open.spotify.com/album/03jk8TVKp0zhwochd99y6t

# %%
# 5) Get songs features from one of my playlists:

# %%
# TODO

# %%
# 6) Get recommendation based on song feature:

# %%
feature= {'danceability': 0.696, 'energy': 0.905, 'key': 2, 'loudness': -2.743, 'mode': 1, 'speechiness': 0.103, 'acousticness': 0.011, 'instrumentalness': 0.000905, 'liveness': 0.302, 'valence': 0.625, 'tempo': 114.944, 'type': 'audio_features', 'id': '11dFghVXANMlKmJXsNCbNl', 'uri': 'spotify:track:11dFghVXANMlKmJXsNCbNl', 'track_href': 'https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11dFghVXANMlKmJXsNCbNl', 'duration_ms': 207960, 'time_signature': 4}

# %%
feature
# Out:
# {'danceability': 0.696,
#  'energy': 0.905,
#  'key': 2,
#  'loudness': -2.743,
#  'mode': 1,
#  'speechiness': 0.103,
#  'acousticness': 0.011,
#  'instrumentalness': 0.000905,
#  'liveness': 0.302,
#  'valence': 0.625,
#  'tempo': 114.944,
#  'type': 'audio_features',
#  'id': '11dFghVXANMlKmJXsNCbNl',
#  'uri': 'spotify:track:11dFghVXANMlKmJXsNCbNl',
#  'track_href': 'https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11dFghVXANMlKmJXsNCbNl',
#  'duration_ms': 207960,
#  'time_signature': 4}

# %%
BASE_REC_URL = "https://api.spotify.com/v1/recommendations?"

url_rec_1 = "https://api.spotify.com/v1/recommendations?seed_artists=4NHQUGzhtTLFvgF5SZesLK&seed_genres=classical%2Ccountry&seed_tracks=0c6xIDDpzE81m2q797ordA&target_liveness=0.302&target_tempo=114.944&target_valence=0.62"
res_rec_1 = api_call(url_rec_1, access_token)
# Out:
# url = https://api.spotify.com/v1/recommendations?seed_artists=4NHQUGzhtTLFvgF5SZesLK&seed_genres=classical%2Ccountry&seed_tracks=0c6xIDDpzE81m2q797ordA&target_liveness=0.302&target_tempo=114.944&target_valence=0.62token = BQDd-wPiNVS58goNCNzQMtQ_1WSi-1MbszEj0R1Nz9yUYrYV15GllGkC-fOw74tFTx2Mqj2fuAbCs6ktCBZk4Ud_EB6Eh45Qkum1R0ICYM-fGK7HK7I

# %%
# Recommendation result

print(res_rec_1)
# Out:
# {'tracks': [{'album': {'album_type': 'ALBUM', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5JdT0LYJdlPbTC58p60WTX'}, 'href': 'https://api.spotify.com/v1/artists/5JdT0LYJdlPbTC58p60WTX', 'id': '5JdT0LYJdlPbTC58p60WTX', 'name': 'Hilary Hahn', 'type': 'artist', 'uri': 'spotify:artist:5JdT0LYJdlPbTC58p60WTX'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/3HdqPF8q38JMFsY9docxFT'}, 'href': 'https://api.spotify.com/v1/albums/3HdqPF8q38JMFsY9docxFT', 'id': '3HdqPF8q38JMFsY9docxFT', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2739cfab16a06d4e13c33eef0ca', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e029cfab16a06d4e13c33eef0ca', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048519cfab16a06d4e13c33eef0ca', 'width': 64}], 'name': 'Brahms & Stravinsky: Violin Concertos', 'release_date': '2001', 'release_date_precision': 'year', 'total_tracks': 7, 'type': 'album', 'uri': 'spotify:album:3HdqPF8q38JMFsY9docxFT'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ie36YytMoKtPiL7tUvmoE'}, 'href': 'https://api.spotify.com/v1/artists/7ie36YytMoKtPiL7tUvmoE', 'id': '7ie36YytMoKtPiL7tUvmoE', 'name': 'Igor Stravinsky', 'type': 'artist', 'uri': 'spotify:artist:7ie36YytMoKtPiL7tUvmoE'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6NUhQz7eAEsZvjEHTKHux9'}, 'href': 'https://api.spotify.com/v1/artists/6NUhQz7eAEsZvjEHTKHux9', 'id': '6NUhQz7eAEsZvjEHTKHux9', 'name': 'Sir Neville Marriner', 'type': 'artist', 'uri': 'spotify:artist:6NUhQz7eAEsZvjEHTKHux9'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/77CaCn32H4mOMQA7UElzfF'}, 'href': 'https://api.spotify.com/v1/artists/77CaCn32H4mOMQA7UElzfF', 'id': '77CaCn32H4mOMQA7UElzfF', 'name': 'Academy of St. Martin in the Fields', 'type': 'artist', 'uri': 'spotify:artist:77CaCn32H4mOMQA7UElzfF'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JdT0LYJdlPbTC58p60WTX'}, 'href': 'https://api.spotify.com/v1/artists/5JdT0LYJdlPbTC58p60WTX', 'id': '5JdT0LYJdlPbTC58p60WTX', 'name': 'Hilary Hahn', 'type': 'artist', 'uri': 'spotify:artist:5JdT0LYJdlPbTC58p60WTX'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'GM',  ...
